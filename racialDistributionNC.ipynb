# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Let's 
raceDistribution = pd.read_csv('/Users/eve65/HackDTech/pikapixels/data_sets/cc-est2019-alldata-37.csv')
raceDistribution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22800 entries, 0 to 22799
# Data columns (total 80 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SUMLEV        22800 non-null  int64
#  1   STATE         22800 non-null  int64
#  2   COUNTY        22800 non-null  int64
#  3   STNAME        22800 non-null  object
#  4   CTYNAME       22800 non-null  object
#  5   YEAR          22800 non-null  int64
#  6   AGEGRP        22800 non-null  int64
#  7   TOT_POP       22800 non-null  int64
#  8   TOT_MALE      22800 non-null  int64
#  9   TOT_FEMALE    22800 non-null  int64
#  10  WA_MALE       22800 non-null  int64
#  11  WA_FEMALE     22800 non-null  int64
#  12  BA_MALE       22800 non-null  int64
#  13  BA_FEMALE     22800 non-null  int64
#  14  IA_MALE       22800 non-null  int64
#  15  IA_FEMALE     22800 non-null  int64
#  16  AA_MALE       22800 non-null  int64
#  17  AA_FEMALE     22800 non-null  int64
# ...

# %%
raceDistribution.head()
# Out:
#    SUMLEV  STATE  COUNTY          STNAME          CTYNAME  YEAR  AGEGRP  \
# 0      50     37       1  North Carolina  Alamance County     1       0
# 1      50     37       1  North Carolina  Alamance County     1       1
# 2      50     37       1  North Carolina  Alamance County     1       2
# 3      50     37       1  North Carolina  Alamance County     1       3
# 4      50     37       1  North Carolina  Alamance County     1       4
#
#    TOT_POP  TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 0   151131     71890       79241  ...       7202         6823        566
# 1     9524      4846        4678  ...        961          941         96
# 2     9889      5126        4763  ...        897          859         84
# 3    10008      5078        4930  ...        726          725         52
# 4    11100      5412        5688  ...        581          596         44
#
#    HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  \
# ...
