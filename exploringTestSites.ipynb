# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
testSites = pd.read_csv('./data_sets/testSitesNational.csv')
testSites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12486 entries, 0 to 12485
# Data columns (total 43 columns):
# X                          12486 non-null float64
# Y                          12486 non-null float64
# OBJECTID                   12486 non-null int64
# facilityid                 1685 non-null object
# name                       12480 non-null object
# fulladdr                   12480 non-null object
# municipality               10834 non-null object
# agency                     10851 non-null object
# agencytype                 10780 non-null object
# phone                      11303 non-null object
# agencyurl                  12376 non-null object
# operhours                  11038 non-null object
# comments                   6959 non-null object
# Instructions               11336 non-null object
# numvehicles                202 non-null float64
# testcapacity               651 non-null float64
# status                     12486 non-null object
# CreationDate               12314 non-null object
# EditDate                   12486 non-null object
# drive_through              10757 non-null object
# appt_only                  11768 non-null object
# referral_required          10446 non-null object
# services_offered_onsite    12454 non-null object
# call_first                 9394 non-null object
# virtual_screening          9477 non-null object
# health_dept_url            11623 non-null object
# State                      12484 non-null object
# GlobalID                   12486 non-null object
# data_source                9868 non-null object
# county                     12267 non-null object
# red_flag                   9348 non-null object
# vol_note                   2147 non-null object
# public_form                12485 non-null object
# start_date                 3085 non-null object
# end_date                   1535 non-null object
# type_of_test               12133 non-null object
# test_processing            11927 non-null object
# fine_print                 8698 non-null object
# vehicle_required           3096 non-null object
# facility_type              11967 non-null object
# Outside_FID                927 non-null float64
# filter                     848 non-null object
# minimum_age                1946 non-null float64
# dtypes: float64(6), int64(1), object(36)
# memory usage: 4.1+ MB

# %%
testSites_condensed = testSites.drop(columns = ['test_processing','data_source','public_form','comments', 'X', 'Y', 'minimum_age','GlobalID','OBJECTID', 'facilityid', 'comments', 'numvehicles', 'testcapacity', 'CreationDate', 'EditDate', 'start_date', 'end_date', 'fine_print', 'vehicle_required', 'Outside_FID', 'filter', 'red_flag', 'vol_note'])

# %%
testSites_condensed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12486 entries, 0 to 12485
# Data columns (total 21 columns):
# name                       12480 non-null object
# fulladdr                   12480 non-null object
# municipality               10834 non-null object
# agency                     10851 non-null object
# agencytype                 10780 non-null object
# phone                      11303 non-null object
# agencyurl                  12376 non-null object
# operhours                  11038 non-null object
# Instructions               11336 non-null object
# status                     12486 non-null object
# drive_through              10757 non-null object
# appt_only                  11768 non-null object
# referral_required          10446 non-null object
# services_offered_onsite    12454 non-null object
# call_first                 9394 non-null object
# virtual_screening          9477 non-null object
# health_dept_url            11623 non-null object
# State                      12484 non-null object
# county                     12267 non-null object
# type_of_test               12133 non-null object
# facility_type              11967 non-null object
# dtypes: object(21)
# memory usage: 2.0+ MB

# %%
testSites_condensed = pd.read_csv('./data_sets/testSitesNational_condensed.csv')

# %%
testSites_byState = testSites_condensed.sort_values(by=['State','county']).set_index(['State'])
testSites_byState.head()
# Out:
#        Unnamed: 0                                   name          fulladdr  \
# State
# AK           8607          ANESIA KUDRIN MEMORIAL CLINIC   113 MAIN STREET
# AK           8608            Anna Hoblet Memorial Clinic       MAIN STREET
# AK           8609                       KING COVE CLINIC         Solcum Dr
# AK           8610  Paul Martin Gundersen Memorial Clinic  General Delivery
# AK           8597                     Atka Health Clinic        Kaangux Ln
#
#         municipality                                       agency  agencytype  \
# State
# AK            Akutan                EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK        False Pass                EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK         King Cove                EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK     Nelson Lagoon                EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK              Atka  ALEUTIAN PRIBILOF ISLANDS ASSOCIATION, INC.  Non Profit
#
#                 phone                agencyurl         operhours Instructions  \
# State
# AK       907-698-2208  http://www.eatribes.org               NaN          NaN
# AK       907-548-2742  http://www.eatribes.org               NaN          NaN
# AK       907-497-2311  http://www.eatribes.org        8 AM - 5PM          NaN
# AK       907-989-2202  http://www.eatribes.org        8 AM - 5PM          NaN
# AK     1(800)478-2742     http://www.apiai.org  8:00 AM -4:30 PM          NaN
#
#            ...      drive_through appt_only referral_required  \
# State      ...
# AK         ...                NaN       NaN               NaN
# AK         ...                NaN       Yes                No
# AK         ...                NaN       Yes                No
# AK         ...                NaN        No                No
# AK         ...                 No        No               Yes
#
#       services_offered_onsite call_first virtual_screening  \
# State
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes                No
#
#                                          health_dept_url          county  \
# State
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians West
#
#                  type_of_test facility_type
# State
# AK                  molecular        Clinic
# AK                  molecular        Clinic
# AK     molecular and antibody        Clinic
# AK                  molecular        Clinic
# AK                  molecular        Clinic
#
# [5 rows x 21 columns]

# %%
testSites_condensed.groupby('county')['fulladdr'].count().sort_values()
# Out:
# county
# Greensville            0
# Lares                  1
# Kingsbury              1
# Kit Carson             1
# Kittitas               1
# Klickitat              1
# La Paz                 1
# La Plata               1
# La Salle               1
# Lakeway                1
# Lander                 1
# Langlade               1
# Lanier                 1
# cook                   1
# Las Piedras            1
# Latah                  1
# Le Flore               1
# Letcher                1
# Lexignton              1
# Lincoln County         1
# Kingman                1
# King George            1
# Kimball                1
# Ketchikan Gateway      1
# Itawamba               1
# James                  1
# Jayuya                 1
# Jeff Davis             1
# Jefferson Davis        1
# Jennings               1
#                     ...
# Fairfield             68
# Worcester             68
# San Bernardino        69
# Seminole              69
# Fresno                70
# Miami-Dade            70
# Palm Beach            72
# Washington            72
# El Paso               73
# Essex                 76
# Tarrant               78
# Philadelphia          79
# Lake                  80
# Riverside             84
# Franklin              88
# Allegheny             88
# Fulton               100
# Maricopa             104
# Bexar                104
# Middlesex            105
# Jefferson            108
# Dallas               109
# Suffolk              114
# Clark                124
# Cook                 125
# San Diego            126
# Montgomery           152
# Harris               171
# Orange               217
# Los Angeles          306
# Name: fulladdr, Length: 1482, dtype: int64

# %%
NC_testSites = testSites_condensed[testSites_condensed.State == 'NC']
NC_testSites.to_csv('./data_sets/NC_testSites.csv')

# %%
NC_testSites.sort_values(by='county').tail()
# Out:
#        Unnamed: 0                                               name  \
# 6366         6366                                 Celo Health Center
# 6367         6367  Toe River Health District- Yancey County Healt...
# 3481         3481                       Mercy Urgent Care Burnsville
# 11183       11183  Cone Health Covid-19 Testing Mount Zion Greens...
# 11880       11880                             Mt Elim Baptist Church
#
#                                                 fulladdr municipality  \
# 6366             116 Seven Mile Ridge Rd, Burnsville, NC   Burnsville
# 6367                               202 Medical Campus Dr   Burnsville
# 3481           41 Charlie Brown Rd, Burnsville, NC 28714   Burnsville
# 11183  1301 Alamance Church Rd, Greensboro, North Car...   Greensboro
# 11880             921 Wilson Road, Red Springs, NC 28377  Red Springs
#
#                                       agency  agencytype           phone  \
# 6366   Mountain Community Health Partnership  Non Profit    828-675-4116
# 6367               Toe River Health District  Non Profit  (828) 682-6118
# 3481                       Mercy Urgent Care     Private  (828) 536-5575
# 11183                            Cone Health     Private             NaN
# 11880                          CORE Response  Non Profit    833-684-0592
#
#                                                agencyurl  \
# 6366                           https://www.mchp.care/cov
# 6367                      http://www.toeriverhealth.org/
# 3481   https://mercyurgentcare.org/news/information-r...
# 11183   https://www.facebook.com/events/268251637823869/
# 11880        https://lumbeetribe.curativeinc.com/welcome
#
#                                                operhours  \
# 6366                         Monday - Friday 8 am – 5 pm
# 6367                                                 NaN
# 3481              Mon.-Fri.: 9am-4pm Sat.-Sun.: 10am-4pm
# 11183  Wednesday in July Only July 1st, 8th, 15th, 22...
# 11880                   August 10th & 11th 10 am to 1 pm
#
#                                             Instructions      ...       \
# 6366                                                 NaN      ...
# 6367                                                 NaN      ...
# 3481   For assessment of symptoms and next-step direc...      ...
# 11183  Drive-up and Walk-up Testing (While Supplies L...      ...
# 11880                  Call or go to website to register      ...
#
#       appt_only referral_required services_offered_onsite call_first  \
# 6366        Yes               NaN   screening and testing        NaN
# 6367        Yes               NaN   screening and testing        NaN
# 3481        Yes                No   screening and testing        Yes
# 11183        No                No            testing only         No
# 11880       Yes               NaN            testing only        Yes
#
#       virtual_screening              health_dept_url State  county  \
# 6366          Available  https://covid19.ncdhhs.gov/    NC  Yancey
# 6367                NaN  https://covid19.ncdhhs.gov/    NC  Yancey
# 3481          Available       http://trhd.dst.nc.us/    NC  Yancey
# 11183               NaN                          NaN    NC     NaN
# 11880                No                          NaN    NC     NaN
#
#       type_of_test facility_type
# 6366     molecular        Clinic
# 6367     molecular        Clinic
# 3481     molecular   Urgent Care
# 11183    molecular       Outdoor
# 11880    molecular       Outdoor
#
# [5 rows x 22 columns]
