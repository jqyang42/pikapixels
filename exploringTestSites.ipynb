# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
testSites = pd.read_csv('/Users/jincho/Desktop/pikapixels/testSitesNational.csv')
testSites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 22 columns):
# X                   117 non-null float64
# Y                   117 non-null float64
# OBJECTID            117 non-null int64
# GlobalID            117 non-null object
# EditDate            117 non-null object
# county              117 non-null object
# address             117 non-null object
# city                117 non-null object
# zipcode             117 non-null int64
# startdate           113 non-null object
# hoursofoperation    116 non-null object
# notes               24 non-null object
# operator            117 non-null object
# POC                 112 non-null object
# Email_Address       31 non-null object
# sitename            115 non-null object
# website             117 non-null object
# daysofoperation     117 non-null object
# publicphone         86 non-null object
# publicnotes         1 non-null object
# SiteUtilization     80 non-null float64
# TurnAroundTime      80 non-null float64
# dtypes: float64(4), int64(2), object(16)
# memory usage: 20.2+ KB

# %%
testSites.head()
# Out:
#               X             Y  OBJECTID  \
# 0 -1.356017e+07  4.825090e+06         3
# 1 -1.335514e+07  4.711182e+06         7
# 2 -1.381775e+07  4.980026e+06        11
# 3 -1.332146e+07  4.346302e+06        15
# 4 -1.361707e+07  4.957866e+06        62
#
#                                  GlobalID             EditDate     county  \
# 0  {0A3C99F8-4E79-41EE-A307-94D2B22CA10F}  2020/07/10 16:24:01      Butte
# 1  {FD62BAF9-D122-43E2-8208-5512D7EE0A11}  2020/07/10 16:24:01  El Dorado
# 2  {A2C39F85-732B-4FF8-AE21-7414CF4DFF97}  2020/07/10 16:24:02   Humboldt
# 3  {E60D0AF1-4305-4E47-A814-101241C921EC}  2020/07/10 16:24:04      Kings
# 4  {151D4F28-4774-4C90-A6C9-ACD82921A5D3}  2020/07/10 16:24:04     Shasta
#
#                   address              city  zipcode            startdate  \
# 0            2357 Fair St             Chico    95928  2020/05/04 06:59:59
# 1         1 College Drive  South Lake Tahoe    96150  2020/05/05 06:59:59
# 2          3750 Harris St            Eureka    95503  2020/04/27 06:59:59
# 3   1520 Kings County Dr.           Hanford    93230  2020/05/04 06:59:59
# 4  11555 Old Oregon Trail           Redding    96003  2020/04/30 06:59:59
#
#        ...          operator               POC Email_Address      sitename  \
# 0      ...        OPTUMServe   Kaylene Robbins           NaN  OPTUMServe 1
# 1      ...        OPTUMServe     Todd Crawford           NaN  OPTUMServe 1
# 2      ...        OPTUMServe   Natalie Chapman           NaN  OPTUMServe 1
# 3      ...        OPTUMServe  Everardo Legaspi           NaN  OPTUMServe 1
# 4      ...        OPTUMServe        Cory Brown           NaN  OPTUMServe 1
#
#                          website             daysofoperation     publicphone  \
# 0  https://lhi.care/covidtesting  Mon, Tues, Wed, Thurs, Fri  (888) 634-1123
# 1  https://lhi.care/covidtesting  Tues, Wed, Thurs, Fri, Sat  (888) 634-1123
# 2  https://lhi.care/covidtesting  Mon, Tues, Wed, Thurs, Fri  (888) 634-1123
# 3  https://lhi.care/covidtesting  Mon, Tues, Wed, Thurs, Fri  (888) 634-1123
# 4  https://lhi.care/covidtesting  Mon, Tues, Wed, Thurs, Fri  (888) 634-1123
#
#   publicnotes SiteUtilization TurnAroundTime
# 0         NaN            92.0          164.0
# 1         NaN           104.0          153.0
# 2         NaN            69.0          174.0
# 3         NaN            87.0           89.0
# 4         NaN            93.0          163.0
#
# [5 rows x 22 columns]

# %%
testSites_byState = testSites_condensed.sort_values(by=['State','county']).set_index(['State'])
testSites_byState.head()
# Out:
#                                         name          fulladdr   municipality  \
# State
# AK             ANESIA KUDRIN MEMORIAL CLINIC   113 MAIN STREET         Akutan
# AK               Anna Hoblet Memorial Clinic       MAIN STREET     False Pass
# AK                          KING COVE CLINIC         Solcum Dr      King Cove
# AK     Paul Martin Gundersen Memorial Clinic  General Delivery  Nelson Lagoon
# AK                        Atka Health Clinic        Kaangux Ln           Atka
#
#                                             agency  agencytype  \
# State
# AK                   EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK                   EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK                   EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK                   EASTERN ALEUTIAN TRIBES, INC.  Non Profit
# AK     ALEUTIAN PRIBILOF ISLANDS ASSOCIATION, INC.  Non Profit
#
#                 phone                agencyurl         operhours Instructions  \
# State
# AK       907-698-2208  http://www.eatribes.org               NaN          NaN
# AK       907-548-2742  http://www.eatribes.org               NaN          NaN
# AK       907-497-2311  http://www.eatribes.org        8 AM - 5PM          NaN
# AK       907-989-2202  http://www.eatribes.org        8 AM - 5PM          NaN
# AK     1(800)478-2742     http://www.apiai.org  8:00 AM -4:30 PM          NaN
#
#                    status drive_through appt_only referral_required  \
# State
# AK                   Open           NaN       NaN               NaN
# AK     Testing Restricted           NaN       Yes                No
# AK                   Open           NaN       Yes                No
# AK                   Open           NaN        No                No
# AK                   Open            No        No               Yes
#
#       services_offered_onsite call_first virtual_screening  \
# State
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes               NaN
# AK      screening and testing        Yes                No
#
#                                          health_dept_url          county  \
# State
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians East
# AK     http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...  Aleutians West
#
#                  type_of_test facility_type
# State
# AK                  molecular        Clinic
# AK                  molecular        Clinic
# AK     molecular and antibody        Clinic
# AK                  molecular        Clinic
# AK                  molecular        Clinic

# %%
testSites_condensed.groupby('county')['fulladdr'].count().sort_values()
# Out:
# county
# Greensville            0
# Lares                  1
# Kingsbury              1
# Kit Carson             1
# Kittitas               1
# Klickitat              1
# La Paz                 1
# La Plata               1
# La Salle               1
# Lakeway                1
# Lander                 1
# Langlade               1
# Lanier                 1
# cook                   1
# Las Piedras            1
# Latah                  1
# Le Flore               1
# Letcher                1
# Lexignton              1
# Lincoln County         1
# Kingman                1
# King George            1
# Kimball                1
# Ketchikan Gateway      1
# Itawamba               1
# James                  1
# Jayuya                 1
# Jeff Davis             1
# Jefferson Davis        1
# Jennings               1
#                     ...
# Fairfield             68
# Worcester             68
# San Bernardino        69
# Seminole              69
# Fresno                70
# Miami-Dade            70
# Palm Beach            72
# Washington            72
# El Paso               73
# Essex                 76
# Tarrant               78
# Philadelphia          79
# Lake                  80
# Riverside             84
# Franklin              88
# Allegheny             88
# Fulton               100
# Maricopa             104
# Bexar                104
# Middlesex            105
# Jefferson            108
# Dallas               109
# Suffolk              114
# Clark                124
# Cook                 125
# San Diego            126
# Montgomery           152
# Harris               171
# Orange               217
# Los Angeles          306
# Name: fulladdr, Length: 1482, dtype: int64
